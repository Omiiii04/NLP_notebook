# %%
# !pip install nltk
""" Alreaduy installed nltk in the environment, so no need to install it again. """
# Out:
# ' Alreaduy installed nltk in the environment, so no need to install it again. '

# %%
corpus = """Hello There !
Here we are to a ML, NLP's.
Dl is remaning. Bye.
"""

# %%
from nltk.tokenize import sent_tokenize

documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ['Hello There !', "Here we are to a ML, NLP's.", 'Dl is remaning.', 'Bye.']

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(corpus)

# %%
words
# Out:
# ['Hello',
#  'There',
#  '!',
#  'Here',
#  'we',
#  'are',
#  'to',
#  'a',
#  'ML',
#  ',',
#  'NLP',
#  "'s",
#  '.',
#  'Dl',
#  'is',
#  'remaning',
#  '.',
#  'Bye',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

punct_words = wordpunct_tokenize(corpus)

# %%
punct_words
# Out:
# ['Hello',
#  'There',
#  '!',
#  'Here',
#  'we',
#  'are',
#  'to',
#  'a',
#  'ML',
#  ',',
#  'NLP',
#  "'",
#  's',
#  '.',
#  'Dl',
#  'is',
#  'remaning',
#  '.',
#  'Bye',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'There',
#  '!',
#  'Here',
#  'we',
#  'are',
#  'to',
#  'a',
#  'ML',
#  ',',
#  "NLP's.",
#  'Dl',
#  'is',
#  'remaning.',
#  'Bye',
#  '.']
