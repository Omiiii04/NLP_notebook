# %%
# To get hands on the wordtovec model from google we will use the gensim library

# %%
#The moedle is about 1.5GB so we will use the gensim library to load the model
#We can get the model from the link https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz

# %%
# Another ref is 
# https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

# %%
# !pip install gensim

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

import gensim.downloader as api
# load the model
model = api.load('word2vec-google-news-300')
# it is the size of 1.5GB so it will take some time to load the model

# %%
# it has 300 dimensions and 3 million words in the vocabulary.
# and has some functions like similarity, most_similar, etc. 
# which we can use to find the similarity between words and find the most similar words to a given word.

# %% [markdown]
# #### I am going to use google colab or kaggle to test the model
# My kaggle link is ***https://www.kaggle.com/omapar***
