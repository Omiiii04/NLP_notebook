# %%
words = ["eat", "eating", "eats", "ate", "eaten", "go", "going", "goes", "went", "gone"]

# %%
from nltk.stem import PorterStemmer

stemming = PorterStemmer()

# %%
for word in words:
    print(f"{word} : {stemming.stem(word)}")
# Out:
# eat : eat
# eating : eat
# eats : eat
# ate : ate
# eaten : eaten
# go : go
# going : go
# goes : goe
# went : went
# gone : gone

# %%
from nltk.stem import SnowballStemmer

sb = SnowballStemmer("english")

# %%
for word in words:
    print(f"{word} : {sb.stem(word)}")
# Out:
# eat : eat
# eating : eat
# eats : eat
# ate : ate
# eaten : eaten
# go : go
# going : go
# goes : goe
# went : went
# gone : gone

# %%
from nltk.stem import RegexpStemmer

rg = RegexpStemmer("ing$|s$|e$", min=4)

# %%
for word in words:
    print(f"{word} : {sb.stem(word)}")
# Out:
# eat : eat
# eating : eat
# eats : eat
# ate : ate
# eaten : eaten
# go : go
# going : go
# goes : goe
# went : went
# gone : gone

# %% [markdown]
# #### Difference between porterstemming and snowball stemming

# %%
# for the words like fairly and aggressively

stemming.stem("fairly")
# Out:
# 'fairli'

# %%
# but as you can for sb

sb.stem("fairly")
# Out:
# 'fair'

# %% [markdown]
# ***difference is clear***
